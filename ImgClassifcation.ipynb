# %%
# IMPORTs
import os
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import PIL
import tensorflow as tf
import tensorflow_hub as hub
import glob


from glob import glob

# %%
# Retrieve Images from Directory
Image_Archive = "C:\\Users\\edgar\\Documents\\Image Archive"
PhotoDumpDir = os.path.join(Image_Archive, "Photo Dump")
CategoriesDir = os.path.join(Image_Archive, "Categories")
FateDir = os.path.join(CategoriesDir, "Fate")



print(f"{Image_Archive} \n. {PhotoDumpDir} \n. {CategoriesDir}")
# Out:
# C:\Users\edgar\Documents\Image Archive
# . C:\Users\edgar\Documents\Image Archive\Photo Dump
# . C:\Users\edgar\Documents\Image Archive\Categories

# %%
for dirpath, dir, files in os.walk(FateDir):
    for filenames in files:
        fname = os.path.join(dirpath, filenames)
        print(f"{fname}")
# Out:
# C:\Users\edgar\Documents\Image Archive\Categories\Fate\12a442e.jpg
# C:\Users\edgar\Documents\Image Archive\Categories\Fate\12f46ff.jpg
# C:\Users\edgar\Documents\Image Archive\Categories\Fate\1320a9d.png
# C:\Users\edgar\Documents\Image Archive\Categories\Fate\1374eec.jpg
# C:\Users\edgar\Documents\Image Archive\Categories\Fate\1411f3c.png
# C:\Users\edgar\Documents\Image Archive\Categories\Fate\1488b15.jpg
# C:\Users\edgar\Documents\Image Archive\Categories\Fate\14cc090.jpg
# C:\Users\edgar\Documents\Image Archive\Categories\Fate\152a514.jpg
# C:\Users\edgar\Documents\Image Archive\Categories\Fate\1543054542947.png
# C:\Users\edgar\Documents\Image Archive\Categories\Fate\1543054695826.png
# C:\Users\edgar\Documents\Image Archive\Categories\Fate\1543406207379.png
# C:\Users\edgar\Documents\Image Archive\Categories\Fate\15e862b.jpg
# C:\Users\edgar\Documents\Image Archive\Categories\Fate\161c6ce.jpg
# C:\Users\edgar\Documents\Image Archive\Categories\Fate\1a2b8dc.jpg
# ...

# %%
m = tf.keras.Sequential([
    hub.KerasLayer("https://tfhub.dev/google/tf2-preview/mobilenet_v2/feature_vector/4", output_shape=[1280],
                   trainable=False),  # Can be True, see below.
    tf.keras.layers.Dense(num_classes, activation='softmax')
])
m.build([None, 224, 224, 3])
